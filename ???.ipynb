# %% [markdown]
# <a href="https://colab.research.google.com/github/viet-8101/colectgames/blob/main/%3F%3F%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mục mới

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 1. Cài thư viện đồ họa (Bắt buộc vì Drive không lưu được cái này)
# !apt-get update && apt-get install -y libcairo2-dev libpango1.0-dev libjpeg-dev libgif-dev librsvg2-dev

# 2. Vào thư mục Bot
# %cd /content/drive/MyDrive/mindcraft

# 3. Dùng npm của hệ thống để cài/build lại canvas (Mất khoảng 1-2 phút)
# !npm install canvas

# %%
# !chmod -R +x /content/drive/MyDrive/bin/node-v22.0.0-linux-x64/bin/

# %%
import os
# Trỏ đường dẫn đến thư mục Node v22 trong Drive của bạn
os.environ['PATH'] = "/content/drive/MyDrive/bin/node-v22.0.0-linux-x64/bin:" + os.environ['PATH']

# Kiểm tra thử xem lên luôn v22 chưa
# !node -v
# Out:
# v22.0.0

# %%
# %cd /content/drive/MyDrive/mindcraft
# !NODE_ENV=production node main.js
# Out:
# /content/drive/MyDrive/mindcraft
# Error getting server: TypeError: Cannot read properties of null (reading 'version')
#     at ping (/content/drive/MyDrive/mindcraft/node_modules/minecraft-protocol/src/ping.js:26:26)
#     at Object.cbPing [as ping] (/content/drive/MyDrive/mindcraft/node_modules/minecraft-protocol/src/ping.js:10:23)
#     at file:///content/drive/MyDrive/mindcraft/src/mindcraft/mcserver.js:21:12
#     at new Promise (<anonymous>)
#     at serverInfo (file:///content/drive/MyDrive/mindcraft/src/mindcraft/mcserver.js:13:12)
#     at getServer (file:///content/drive/MyDrive/mindcraft/src/mindcraft/mcserver.js:130:24)
#     at Module.createAgent (file:///content/drive/MyDrive/mindcraft/src/mindcraft/mindcraft.js:48:34)
#     at file:///content/drive/MyDrive/mindcraft/main.js:79:15
#     at ModuleJob.run (node:internal/modules/esm/module_job:235:25)
#     at async ModuleLoader.import (node:internal/modules/esm/loader:461:24)
# Attempting to connect anyway...
# ...
