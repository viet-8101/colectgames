# %% [markdown]
# <a href="https://colab.research.google.com/github/viet-8101/colectgames/blob/main/%3F%3F%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mục mới

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Tạo thư mục chứa node trong Drive
# !mkdir -p /content/drive/MyDrive/bin
# %cd /content/drive/MyDrive/bin

# Tải Node v22 bản chính thức cho Linux
# !wget https://nodejs.org/dist/v22.0.0/node-v22.0.0-linux-x64.tar.xz
# !tar -xf node-v22.0.0-linux-x64.tar.xz
# !rm node-v22.0.0-linux-x64.tar.xz
# Out:
# /content/drive/MyDrive/bin
# --2026-05-04 14:46:45--  https://nodejs.org/dist/v22.0.0/node-v22.0.0-linux-x64.tar.xz
# Resolving nodejs.org (nodejs.org)... 104.16.212.131, 104.16.213.131, 2606:4700::6810:d483, ...
# Connecting to nodejs.org (nodejs.org)|104.16.212.131|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27783576 (26M) [application/x-xz]
# Saving to: ‘node-v22.0.0-linux-x64.tar.xz’
#
# node-v22.0.0-linux- 100%[===================>]  26.50M  39.3MB/s    in 0.7s
#
# 2026-05-04 14:46:46 (39.3 MB/s) - ‘node-v22.0.0-linux-x64.tar.xz’ saved [27783576/27783576]

# %%
import os
# Trỏ đường dẫn đến thư mục Node v22 trong Drive của bạn
os.environ['PATH'] = "/content/drive/MyDrive/bin/node-v22.0.0-linux-x64/bin:" + os.environ['PATH']

# Kiểm tra thử xem lên luôn v22 chưa
# !node -v
# Out:
# v22.0.0

# %%
# !fuser -k 8080/tcp
# %cd /content/drive/MyDrive/mindcraft
# !node main.js
# Out:
# /content/drive/MyDrive/mindcraft
