# %% [markdown]
# <a href="https://colab.research.google.com/github/viet-8101/colectgames/blob/main/Ch%C3%A0o_m%E1%BB%ABng_b%E1%BA%A1n_%C4%91%E1%BA%BFn_v%E1%BB%9Bi_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Gắn kết Google Drive
#
# Để sử dụng các tệp của bạn, chúng ta cần gắn kết Google Drive vào Colab. Hãy chạy ô mã dưới đây và làm theo hướng dẫn để cấp quyền.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/AI/
# Out:
# ls: cannot access '/content/drive/MyDrive/AI/': No such file or directory

# %%
import os

# Thay đổi thư mục làm việc hiện tại sang thư mục chứa train.py
os.chdir('/content/drive/MyDrive/AI/')

# Chạy train.py
# !python train.py
# Out:
# Using device: cuda
# /content/drive/MyDrive/AI/train.py:49: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/drive/MyDrive/AI/train.py:72: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 0 | Loss: 4.9164
# Epoch 1 | Loss: 2.6443
# Epoch 2 | Loss: 0.8096
# Epoch 3 | Loss: 0.1770
# Epoch 4 | Loss: 0.0756
# Epoch 5 | Loss: 0.0591
# Epoch 6 | Loss: 0.0510
# Epoch 7 | Loss: 0.0459
# Epoch 8 | Loss: 0.0413
# Epoch 9 | Loss: 0.0388
# Epoch 10 | Loss: 0.0373
# Epoch 11 | Loss: 0.0359
# Epoch 12 | Loss: 0.0343
# Epoch 13 | Loss: 0.0327
# Epoch 14 | Loss: 0.0317
# Epoch 15 | Loss: 0.0310
# Epoch 16 | Loss: 0.0304
# Epoch 17 | Loss: 0.0298
# Epoch 18 | Loss: 0.0294
# Epoch 19 | Loss: 0.0289
# 🔥 Training hoàn tất!

# %% [markdown]
# Ô mã trên sẽ thay đổi thư mục làm việc hiện tại sang `/content/drive/MyDrive/AI/` và sau đó chạy tệp `train.py`. Nếu `train.py` cần các tệp `data.pt` và `tokenizer.json` trong cùng thư mục, nó sẽ tìm thấy chúng.
